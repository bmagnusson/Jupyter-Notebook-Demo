# %% [markdown]
# # Jupyter Notebook Demo
# Here I will show a few of the basic data visualation and minipulation tools available with Python Pandas.
#
# Here is a Pandas [cheatsheet](https://assets.datacamp.com/blog_assets/PandasPythonForDataScience.pdf)
#
# I grabbed one year of electricity data for demonstration purposes. **production** means solar production during the given interval in watthours. **consumption** means the electricity consumed by the house in watthours. The goal will be to simply examine the data more closely. Sources:
# * [Production](http://www.soda-is.com/eng/services/services_radiation_free_eng.php)
# * [Consumption](http://www.smartgridaustralia.com.au/)

# %%
import pandas as pd

# %% [markdown]
# ## Read data from csv
# By default, notebooks display about 30 rows from the start and 30 rows from the end of the tabulated data.

# %%
df = pd.read_csv('data.csv', index_col=0, parse_dates=[0])
df
# Out:
#                      consumption  production
# datetime
# 2013-01-01 00:00:00         52.0           0
# 2013-01-01 00:30:00        115.0           0
# 2013-01-01 01:00:00         18.0           0
# 2013-01-01 01:30:00        104.0           0
# 2013-01-01 02:00:00         17.0           0
# 2013-01-01 02:30:00        125.0           0
# 2013-01-01 03:00:00        132.0           0
# 2013-01-01 03:30:00        114.0           0
# 2013-01-01 04:00:00        107.0           0
# 2013-01-01 04:30:00        106.0           0
# 2013-01-01 05:00:00        105.0          12
# 2013-01-01 05:30:00         56.0          77
# 2013-01-01 06:00:00         59.0         186
# 2013-01-01 06:30:00         86.0         311
# 2013-01-01 07:00:00         87.0         448
# 2013-01-01 07:30:00        128.0         569
# 2013-01-01 08:00:00         31.0         681
# 2013-01-01 08:30:00        107.0         779
# 2013-01-01 09:00:00         20.0         870
# 2013-01-01 09:30:00        849.0         948
# 2013-01-01 10:00:00        192.0        1005
# 2013-01-01 10:30:00        203.0        1051
# 2013-01-01 11:00:00        147.0        1097
# 2013-01-01 11:30:00        148.0        1116
# 2013-01-01 12:00:00        145.0        1124
# 2013-01-01 12:30:00        142.0        1101
# 2013-01-01 13:00:00        102.0        1047
# 2013-01-01 13:30:00         55.0        1002
# 2013-01-01 14:00:00        598.0         941
# 2013-01-01 14:30:00         91.0         865
# ...                          ...         ...
# 2013-12-31 09:00:00         20.0           0
# 2013-12-31 09:30:00        893.0           0
# 2013-12-31 10:00:00        192.0           0
# 2013-12-31 10:30:00        124.0           0
# 2013-12-31 11:00:00        133.0           0
# 2013-12-31 11:30:00        116.0           0
# 2013-12-31 12:00:00        107.0           0
# 2013-12-31 12:30:00        105.0           0
# 2013-12-31 13:00:00         24.0           0
# 2013-12-31 13:30:00        620.0           0
# 2013-12-31 14:00:00       1275.0           0
# 2013-12-31 14:30:00       1062.0           0
# 2013-12-31 15:00:00        472.0          11
# 2013-12-31 15:30:00        162.0          68
# 2013-12-31 16:00:00         84.0         168
# 2013-12-31 16:30:00        127.0         297
# 2013-12-31 17:00:00         91.0         419
# 2013-12-31 17:30:00        550.0         534
# 2013-12-31 18:00:00         83.0         641
# 2013-12-31 18:30:00        128.0         741
# 2013-12-31 19:00:00        172.0         831
# 2013-12-31 19:30:00        173.0         913
# 2013-12-31 20:00:00        166.0         972
# 2013-12-31 20:30:00        166.0        1017
# 2013-12-31 21:00:00        118.0        1063
# 2013-12-31 21:30:00        182.0        1076
# 2013-12-31 22:00:00         90.0        1075
# 2013-12-31 22:30:00        164.0        1059
# 2013-12-31 23:00:00        658.0        1011
# 2013-12-31 23:30:00        128.0         960
#
# [17452 rows x 2 columns]

# %% [markdown]
# We can use `DataFrame.head(n)` and `DataFrame.tail(n)` to display the `n` rows at the beginning or end. Note that when you use `print()` you don't get the nice table output.

# %%
print("Head of df")
print(df.head(10))
print("\nTail of df")
df.tail(10)
# Out:
# Head of df
#                      consumption  production
# datetime
# 2013-01-01 00:00:00         52.0           0
# 2013-01-01 00:30:00        115.0           0
# 2013-01-01 01:00:00         18.0           0
# 2013-01-01 01:30:00        104.0           0
# 2013-01-01 02:00:00         17.0           0
# 2013-01-01 02:30:00        125.0           0
# 2013-01-01 03:00:00        132.0           0
# 2013-01-01 03:30:00        114.0           0
# 2013-01-01 04:00:00        107.0           0
# 2013-01-01 04:30:00        106.0           0
#
# Tail of df
#                      consumption  production
# datetime
# 2013-12-31 19:00:00        172.0         831
# 2013-12-31 19:30:00        173.0         913
# 2013-12-31 20:00:00        166.0         972
# 2013-12-31 20:30:00        166.0        1017
# 2013-12-31 21:00:00        118.0        1063
# 2013-12-31 21:30:00        182.0        1076
# 2013-12-31 22:00:00         90.0        1075
# 2013-12-31 22:30:00        164.0        1059
# 2013-12-31 23:00:00        658.0        1011
# 2013-12-31 23:30:00        128.0         960

# %% [markdown]
# We can see that we have one year of data in 30 minute incriments from the year 2013.
#
# # Plot the data
# Jupyter supports two options for plotting with matplotlib, *inline* (static) and *notebook* (interactive).

# %%
# %matplotlib inline
df.plot()

# %% [markdown]
# Crap. Something looks funny with the production data. What's going on?! Let's use an interactive plot so we can zoom in.

# %%
# %matplotlib notebook
df.plot(figsize=(13,8), subplots=True)
df.describe()
# Out:
# <img src="data:image/png;base64,...">
#         consumption    production
# count  17452.000000  17452.000000
# mean     203.391875    246.869241
# std      260.286904    338.882152
# min        9.000000      0.000000
# 25%       69.000000      0.000000
# 50%      110.000000      1.000000
# 75%      170.000000    501.000000
# max     2960.000000   1141.000000

# %% [markdown]
# Looks like some missing data! Let's look at production data with the value of -999.

# %%
df['production'][df['production'] == -999].describe()
# Out:
# count    154.0
# mean    -999.0
# std        0.0
# min     -999.0
# 25%     -999.0
# 50%     -999.0
# 75%     -999.0
# max     -999.0
# Name: production, dtype: float64

# %% [markdown]
# Ruhroh. 154 missing data points! And now the eternal question of how to handle missing data. Set to NaN? Set to 0? Throw it out completely? I'll set to 0 for now.

# %%
df.loc[df.production == -999, 'production'] = 0
df.describe()
# Out:
#         consumption    production
# count  17452.000000  17452.000000
# mean     203.391875    246.869241
# std      260.286904    338.882152
# min        9.000000      0.000000
# 25%       69.000000      0.000000
# 50%      110.000000      1.000000
# 75%      170.000000    501.000000
# max     2960.000000   1141.000000

# %% [markdown]
# Be careful! This edits the variable `df` in the kernel, so all cells now use this updated `df`. Rerun the plotting cells above to see the difference.
#
# ## Save this notebook!
# *File* --> *Download As*
